# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import pandas as pd
df = pd.read_excel("jamu.xlsx")
df.head()
# Out:
#    Unnamed: 0                                        keyword
# 0           0                              Accounting Forums
# 1           1            Accounting Information System (AIS)
# 2           2                              Accounting Method
# 3           3                                Accrued Expense
# 4           4  Accumulated Other Comprehensive Income (AOCI)

# %%
df.drop(['Unnamed: 1', 'Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8'], axis = 1)
# Out:
#                                 Keyword
# 0                           2/10 Net 30
# 1                    Absorption Costing
# 2              Accelerated Depreciation
# 3                            Accountant
# 4                            Accounting
# ..                                  ...
# 521  What Makes a Good Financial Model?
# 522             Working Capital Formula
# 523                         XIRR vs IRR
# 524                                REFM
# 525          DCF Terminal Value Formula
#
# [526 rows x 1 columns]

# %%
driver = webdriver.Edge(r'C:\Users\user\Downloads\msedgedriver.exe')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10412\1427375144.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(r'C:\Users\user\Downloads\msedgedriver.exe')

# %%
driver.get('https://member.seotoolsrush.com/login?amember_redirect_url=https%3A%2F%2Fmember.seotoolsrush.com%2Fpage%2FXEMRush%2BReload')
box = driver.find_element_by_xpath('//*[@id="amember-login"]')
box.send_keys('seotoolsagency')
box.send_keys(Keys.ENTER)
box2 = driver.find_element_by_xpath('//*[@id="amember-pass"]')
box2.send_keys('seotoolsagency-EYG6aySRdj7p')
box2.send_keys(Keys.ENTER)
select = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div[2]/div[1]/div/form/fieldset/div[4]/div/input')
action = ActionChains(driver)
action.click(on_element = select)
action.perform()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10412\3057960320.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   box = driver.find_element_by_xpath('//*[@id="amember-login"]')
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# c:\Users\user\Desktop\ART BOT\JAMU16.IPYNB Cell 4' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/ART%20BOT/JAMU16.IPYNB#ch0000003?line=0'>1</a> driver.get('https://member.seotoolsrush.com/login?amember_redirect_url=https%3A%2F%2Fmember.seotoolsrush.com%2Fpage%2FXEMRush%2BReload')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/ART%20BOT/JAMU16.IPYNB#ch0000003?line=1'>2</a> box = driver.find_element_by_xpath('//*[@id="amember-login"]')
# ...

# %%
select = driver.find_element_by_xpath('//*[@id="accordion-content-seo"]/div/div[3]/div[1]/a/span')
action = ActionChains(driver)
action.click(on_element = select)
action.perform()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10412\1785199820.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   select = driver.find_element_by_xpath('//*[@id="accordion-content-seo"]/div/div[3]/div[1]/a/span')

# %%
iterator = 0

# %%
import time 
df = pd.read_excel("jamu.xlsx")
df.head()

df2 = pd.read_excel("jamu1.xlsx")

list1 =df['keyword'].tolist()
list2 = df2['globalvolume'].tolist()
list3 = df2['keyword'].tolist()
error =[]

for i in range(0,len(list1)):
    
    try:
        print(list1[i])
        box = driver.find_element_by_xpath('//*[@id="app"]/div/div/div[1]/section/div[2]/div[2]/div/div/div/div/div/span/div')
        box.send_keys(list1[i])
        box.send_keys(Keys.ENTER)
        select = driver.find_element_by_xpath('//*[@id="app"]/div/div/div[1]/section/div[2]/div[3]/div/div[2]/button/span/span')
        action = ActionChains(driver)
        action.click(on_element = select)
        action.perform()
        time.sleep(8)
        text1 = driver.find_element_by_xpath('//*[@id="app"]/div/div/div/div[6]/div[2]/div/div[2]/div/div/div[2]/div/div[1]/span').text
        list2.append(text1)
        list3.append(list1[i])
        driver.execute_script("window.history.go(-1)")
        
    except:
        error.append(list1[i])
        driver.execute_script("window.history.go(-1)")
# Out:
# Accounting Information System (AIS)
# C:\Users\user\AppData\Local\Temp\ipykernel_10412\2411124524.py:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   box = driver.find_element_by_xpath('//*[@id="app"]/div/div/div[1]/section/div[2]/div[2]/div/div/div/div/div/span/div')
# C:\Users\user\AppData\Local\Temp\ipykernel_10412\2411124524.py:19: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   select = driver.find_element_by_xpath('//*[@id="app"]/div/div/div[1]/section/div[2]/div[3]/div/div[2]/button/span/span')
# C:\Users\user\AppData\Local\Temp\ipykernel_10412\2411124524.py:24: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   text1 = driver.find_element_by_xpath('//*[@id="app"]/div/div/div/div[6]/div[2]/div/div[2]/div/div/div[2]/div/div[1]/span').text
# Accumulated Other Comprehensive Income (AOCI)
# ...

# %%
len(list3)
len(list2)
# Out:
# 419

# %%
data1 ={
    'keyword':list3,
        'globalvolume':list2
}
df2 = pd.DataFrame(data1)
df2.to_excel("jamu1.xlsx")

# %%
data ={
    'keyword':error,
        
}
df2 = pd.DataFrame(data)
df2.to_excel("jamu.xlsx")

# %%
# Out:
# ['Absorption Costing',
#  'Accelerated Depreciation',
#  'Accounting Depreciation vs Tax Depreciation',
#  'Accounting Ethics',
#  'Accounting Forums',
#  'Accounting Information System (AIS)',
#  'Accounting Method',
#  'Accounting Profit',
#  'Accounting Ratios',
#  'Accounting Transactions',
#  'Accounts Expenses',
#  'Accounts Payable Turnover Ratio',
#  'Accounts Receivable Aging',
#  'Accounts Receivable Aging Report',
#  'Accounts Receivable Turnover Ratio',
#  'Accrued Expense',
#  'Accrued Expenses',
#  'Accrued Interest',
#  'Accrued Liability',
#  'Accumulated Depreciation',
#  'Accumulated Other Comprehensive Income (AOCI)',
#  'Activity Cost Driver',
#  'Activity-Based Budgeting',
#  'Actuarial Gains or Losses',
#  'Additional Paid In Capital',
#  'Additional Paid-In Capital vs. Contributed Capital',
#  'Adjusted Gross Income (AGI)',
#  'Adjusting Journal Entry',
#  'After-Tax Income',
#  'Allowance for Doubtful Accounts',
#  'Alternative Depreciation System (ADS)',
# ...

# %%
box = driver.find_element_by_xpath('//*[@id="amember-login"]')
box.send_keys('seotoolsagency')
box.send_keys(Keys.ENTER)
box2 = driver.find_element_by_xpath('//*[@id="amember-pass"]')
box2.send_keys('seotoolsagency-EYG6aySRdj7p')
box2.send_keys(Keys.ENTER)
select = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div[2]/div[1]/div/form/fieldset/div[4]/div/input')
action = ActionChains(driver)
action.click(on_element = select)
action.perform()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6300\1171612316.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   box = driver.find_element_by_xpath('//*[@id="amember-login"]')
# C:\Users\user\AppData\Local\Temp\ipykernel_6300\1171612316.py:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   box2 = driver.find_element_by_xpath('//*[@id="amember-pass"]')
# C:\Users\user\AppData\Local\Temp\ipykernel_6300\1171612316.py:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   select = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div/div[1]/div[2]/div[1]/div/form/fieldset/div[4]/div/input')

# %%
error2 =[]
for i in range(0,len(error)):
    
    try:
        box = driver.find_element_by_xpath('//*[@id="app"]/div/div/div[1]/section/div[2]/div[2]/div/div/div/div/div/span/div')
        box.send_keys(error[i])
        box.send_keys(Keys.ENTER)
        select = driver.find_element_by_xpath('//*[@id="app"]/div/div/div[1]/section/div[2]/div[3]/div/div[2]/button/span/span')
        action = ActionChains(driver)
        action.click(on_element = select)
        action.perform()
        time.sleep(3)
        text1 = driver.find_element_by_xpath('//*[@id="app"]/div/div/div/div[6]/div[2]/div/div[2]/div/div/div[2]/div/div[1]/span').text
        list2.append(text1)
        list3.append(error[i])
        driver.execute_script("window.history.go(-1)")
        
    except:
        error2.append(error[i])
        driver.execute_script("window.history.go(-1)")
# Out:
# 383

# %%
data ={
    'keyword':list3,
        'globalvolume':list2
}
df2 = pd.DataFrame(data)
df2.to_excel("jamu2.xlsx")

# %%
a=list3
print(len(list1))
print(len(list3))
x =set(list1)
y= x -set(list3)
print(len(y))
# Out:
# 526
# 177
# 349

# %%
list1 = list(y)
for i in range(0,len(list1)):
    print(list1[i])
    try:
        
        box = driver.find_element_by_xpath('//*[@id="app"]/div/div/div[1]/section/div[2]/div[2]/div/div/div/div/div/span/div')
        box.send_keys(list1[i])
        box.send_keys(Keys.ENTER)
        select = driver.find_element_by_xpath('//*[@id="app"]/div/div/div[1]/section/div[2]/div[3]/div/div[2]/button/span/span')
        action = ActionChains(driver)
        action.click(on_element = select)
        action.perform()
        time.sleep(6)
        text1 = driver.find_element_by_xpath('//*[@id="app"]/div/div/div/div[6]/div[2]/div/div[2]/div/div/div[2]/div/div[1]/span').text
        list2.append(text1)
        list3.append(list1[i])
        driver.execute_script("window.history.go(-1)")
        
    except:
        
        driver.execute_script("window.history.go(-1)")
# Out:
# Variable Overhead
# C:\Users\user\AppData\Local\Temp\ipykernel_6116\2411968088.py:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   box = driver.find_element_by_xpath('//*[@id="app"]/div/div/div[1]/section/div[2]/div[2]/div/div/div/div/div/span/div')
# C:\Users\user\AppData\Local\Temp\ipykernel_6116\2411968088.py:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   select = driver.find_element_by_xpath('//*[@id="app"]/div/div/div[1]/section/div[2]/div[3]/div/div[2]/button/span/span')
# C:\Users\user\AppData\Local\Temp\ipykernel_6116\2411968088.py:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   text1 = driver.find_element_by_xpath('//*[@id="app"]/div/div/div/div[6]/div[2]/div/div[2]/div/div/div[2]/div/div[1]/span').text
# Gross vs Net
# Warranty Expense
# What is a Financial Model?
# Accounting Standard
# ...
